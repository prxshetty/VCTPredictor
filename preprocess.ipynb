# %%
import requests
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
def fetch_news():
    url = "https://vlrggapi.vercel.app/news"
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching news: {e}")
        return None

# %%
fetch_data(5)
# Out:
# {'data': {'status': 200,
#   'segments': [{'title': 'Sayaplayer announces restricted free agency',
#     'description': 'Sayaplayer announces he is LFT after two years with T1',
#     'date': 'July 25, 2024',
#     'author': 'thothgow',
#     'url_path': 'https://vlr.gg/379835/sayaplayer-announces-restricted-free-agency'},
#    {'title': 'Champions 2024 opening matches drawn',
#     'description': 'Less than two weeks remain before Champions Seoul kicks off.',
#     'date': 'July 21, 2024',
#     'author': 'Seulgi',
#     'url_path': 'https://vlr.gg/378553/champions-2024-opening-matches-drawn'},
#    {'title': 'Leviatán defeat G2, take Americas trophy',
#     'description': 'In the Stage 2 playoffs final, Leviatán took down favorite G2 esports to claim their first VCT Americas championship.',
#     'date': 'July 21, 2024',
#     'author': 'PancakeGOAT',
#     'url_path': 'https://vlr.gg/378634/leviat-n-defeat-g2-take-americas-trophy'},
#    {'title': 'Gen.G claim third VCT title with 3-1 win over DRX',
#     'description': 'Gen.G are still the top dogs.',
#     'date': 'July 21, 2024',
#     'author': 'DavisEZ',
#     'url_path': 'https://vlr.gg/378263/gen-g-claim-third-vct-title-with-3-1-win-over-drx'},
#    {'title': 'Leviatán win rollercoaster vs. KRÜ, reach first Americas final',
#     'description': 'G2 Esports and Leviatán will face off in the grand final for a chance to win Americas Stage 2.',
#     'date': 'July 20, 2024',
#     'author': 'PancakeGOAT',
#     'url_path': 'https://vlr.gg/378023/leviat-n-win-rollercoaster-vs-kr-reach-first-americas-final'},
#    {'title': 'FNATIC triumph over Vitality to reclaim EMEA crown',
#     'description': 'FNATIC beat Team Vitality 3-1 in the EMEA Stage 2 grand finals to reclaim their regional crown.',
#     'date': 'July 20, 2024',
#     'author': 'raezeri',
#     'url_path': 'https://vlr.gg/377761/fnatic-triumph-over-vitality-to-reclaim-emea-crown'},
#    {'title': 'EDG continue dynasty with 3-2 over FPX',
#     'description': 'EDG extend local winstreak to eight events in a row on their way to top seed at Champions.',
#     'date': 'July 20, 2024',
#     'author': 'thothgow',
#     'url_path': 'https://vlr.gg/377594/edg-continue-dynasty-with-3-2-over-fpx'},
#    {'title': 'DRX reverse sweep Paper Rex to reach Pacific grand final',
#     'description': 'DRX break head-to-head streak to guarantee Korean glory at Pacific final',
#     'date': 'July 20, 2024',
#     'author': 'thothgow',
#     'url_path': 'https://vlr.gg/377561/drx-reverse-sweep-paper-rex-to-reach-pacific-grand-final'},
#    {'title': 'KRÜ round out Champions team list with 2-1 win over 100 Thieves',
#     'description': 'KRU have attended every Champions to date.',
#     'date': 'July 19, 2024',
#     'author': 'DavisEZ',
#     'url_path': 'https://vlr.gg/377246/kr-round-out-champions-team-list-with-2-1-win-over-100-thieves'},
#    {'title': 'Leviatán swept for first time in VCT 2024 by G2 in upper finals',
#     'description': 'G2 Esports swept Leviatán at the VCT Americas 2024 Stage 2 playoff upper finals to secure their spot in the regional finals.',
#     'date': 'July 19, 2024',
#     'author': 'weivy',
#     'url_path': 'https://vlr.gg/376939/leviat-n-swept-for-first-time-in-vct-2024-by-g2-in-upper-finals'},
#    {'title': 'Team Vitality reach EMEA finals, defeat Team Heretics 3-1',
#     'description': 'Team Vitality earned their first best-of-five series win of the year on their first attempt, beating Team Heretics 3-1.',
#     'date': 'July 19, 2024',
#     'author': 'weivy',
#     'url_path': 'https://vlr.gg/376768/team-vitality-reach-emea-finals-defeat-team-heretics-3-1'},
#    {'title': 'FPX reverse sweep Trace to make VCT China finals',
#     'description': 'Trace narrowly missed out on their first VCT China final.',
#     'date': 'July 19, 2024',
#     'author': 'DavisEZ',
#     'url_path': 'https://vlr.gg/376592/fpx-reverse-sweep-trace-to-make-vct-china-finals'},
#    {'title': 'G2 defeat 100T 2-0 to qualify for Champions ',
#     'description': 'G2 defeat 100T 2-0 to qualify for Champions',
#     'date': 'July 18, 2024',
#     'author': 'Paulwall918',
#     'url_path': 'https://vlr.gg/376462/g2-defeat-100t-2-0-to-qualify-for-champions'},
#    {'title': 'Leviatán dominate El Clásico with 2-0 over KRÜ Esports',
#     'description': 'On their way to the Americas grand final, Leviatán go up 7-6 in the LATAM rivalry.',
#     'date': 'July 18, 2024',
#     'author': 'thothgow',
#     'url_path': 'https://vlr.gg/376361/leviat-n-dominate-el-cl-sico-with-2-0-over-kr-esports'},
#    {'title': 'FPX set up lower final rematch against Trace Esports',
#     'description': 'Today’s result also gets FPX a better seed for Champions, while BLG are relegated to the fourth seed.',
#     'date': 'July 18, 2024',
#     'author': 'eutalyx',
#     'url_path': 'https://vlr.gg/376113/fpx-set-up-lower-final-rematch-against-trace-esports'},
#    {'title': 'EDG triumph in 2-0 sweep against Trace Esports',
#     'description': 'ZmjjKK and EDG stomped over Trace Esports to get to their second regional final of 2024.',
#     'date': 'July 18, 2024',
#     'author': 'weivy',
#     'url_path': 'https://vlr.gg/376095/edg-triumph-in-2-0-sweep-against-trace-esports'},
#    {'title': '100T defeat Sentinels 2-0 to advance in Americas playoffs ',
#     'description': '100T defeat Sentinels 2-0 to keep their Champions hopes alive',
#     'date': 'July 17, 2024',
#     'author': 'Paulwall918',
#     'url_path': 'https://vlr.gg/375981/100t-defeat-sentinels-2-0-to-advance-in-americas-playoffs'},
#    {'title': 'KRÜ eliminate Cloud9 and keep Champions dreams alive',
#     'description': 'The first match of the VCT Americas playoffs saw KRÜ Esports defeat Cloud9 2-1, and move on to the upper semifinals.',
#     'date': 'July 17, 2024',
#     'author': 'redlight',
#     'url_path': 'https://vlr.gg/375506/kr-eliminate-cloud9-and-keep-champions-dreams-alive'},
#    {'title': 'Heretics knock FUT out of playoffs, advance to lower final',
#     'description': 'Heretics have defeated FUT 2-0 in the lower bracket to advance to the EMEA lower final.',
#     'date': 'July 17, 2024',
#     'author': 'raezeri',
#     'url_path': 'https://vlr.gg/375420/heretics-knock-fut-out-of-playoffs-advance-to-lower-final'},
#    {'title': 'FNATIC advance to grand final with a 2-0 win over Vitality',
#     'description': 'FNATIC have confirmed their second regional grand final of the year with a 2-0 win over Team Vitality.',
#     'date': 'July 17, 2024',
#     'author': 'Zahk',
#     'url_path': 'https://vlr.gg/375345/fnatic-advance-to-grand-final-with-a-2-0-win-over-vitality'},
#    {'title': 'EDG maintain flawless record over BLG',
#     'description': 'Today’s win is a step towards yet another regional title. Overall, it would be the 12th Chinese title EDG would be able to add to their trophy case. But it will not be that simple.',
#     'date': 'July 17, 2024',
#     'author': 'eutalyx',
#     'url_path': 'https://vlr.gg/375262/edg-maintain-flawless-record-over-blg'},
#    {'title': 'Trace send FPX to the lower bracket with 2-0 win',
#     'description': 'After a stomp and denied comeback, Trace defeated FPX 2-0',
#     'date': 'July 17, 2024',
#     'author': 'thothgow',
#     'url_path': 'https://vlr.gg/375240/trace-send-fpx-to-the-lower-bracket-with-2-0-win'},
#    {'title': 'FNATIC reach EMEA upper finals over FUT',
#     'description': 'FNATIC have beaten FUT Esports 2-0, sending FUT to the lower bracket and moving on to the upper final against Vitality.',
#     'date': 'July 16, 2024',
#     'author': 'eutalyx',
#     'url_path': 'https://vlr.gg/375111/fnatic-reach-emea-upper-finals-over-fut'},
#    {'title': 'Leviatán, G2 claim top two spots in the Americas Playoffs',
#     'description': 'Leviatán, G2 claim top two spots in the Americas Playoffs',
#     'date': 'July 16, 2024',
#     'author': 'Paulwall918',
#     'url_path': 'https://vlr.gg/375038/leviat-n-g2-claim-top-two-spots-in-the-americas-playoffs'},
#    {'title': 'Vitality best Heretics and lock in Champions slot',
#     'description': "A world-class performance from Sayf in map two laid the tracks for Vitality's first qualification to an international LAN.",
#     'date': 'July 16, 2024',
#     'author': 'eutalyx',
#     'url_path': 'https://vlr.gg/374956/vitality-best-heretics-and-lock-in-champions-slot'},
#    {'title': 'FNATIC continue with hiro, add doma and Anderzz',
#     'description': "FNATIC hiro will continue playing in Leo's stead for the rest of 2024. Anderzz and doma will round out the team's support squad.",
#     'date': 'July 16, 2024',
#     'author': 'raezeri',
#     'url_path': 'https://vlr.gg/374875/fnatic-continue-with-hiro-add-doma-and-anderzz'},
#    {'title': 'Bilibili sweep JDG to secure Champions slot',
#     'description': 'Bilibili Gaming rolled over JDG Esports 2-0 in the first round of the VCT China: Stage 2 playoffs. They have also secured Champions qualification via points.',
#     'date': 'July 16, 2024',
#     'author': 'eutalyx',
#     'url_path': 'https://vlr.gg/374733/bilibili-sweep-jdg-to-secure-champions-slot'},
#    {'title': 'Trace breeze past All Gamers to make Champions',
#     'description': 'Trace are the first team to make it out of single elimination in VCT China.',
#     'date': 'July 16, 2024',
#     'author': 'DavisEZ',
#     'url_path': 'https://vlr.gg/374675/trace-breeze-past-all-gamers-to-make-champions'},
#    {'title': 'NRG release Victor and Chet, Demon1 returns as starter',
#     'description': 'No more crashies and food.',
#     'date': 'July 15, 2024',
#     'author': 'ChickenJoe',
#     'url_path': 'https://vlr.gg/374535/nrg-release-victor-and-chet-demon1-returns-as-starter'},
#    {'title': 'FNATIC bounce back against KCorp in 2-1 victory',
#     'description': 'FNATIC kickstarted their VCT EMEA Stage 2 playoffs run by eliminating Karmine Corp in a 2-1 victory. FNC return to competition tomorrow in the upper semifinal against FUT.',
#     'date': 'July 15, 2024',
#     'author': 'eutalyx',
#     'url_path': 'https://vlr.gg/374332/fnatic-bounce-back-against-kcorp-in-2-1-victory'}]}}

# %%
def preprocess_data(data):
    df=pd.DataFrame(data)
    df
