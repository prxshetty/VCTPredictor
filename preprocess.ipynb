# %%
import requests
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
def fetch_data(endpoint, params=None):
    base_url = "https://vlrggapi.vercel.app"
    url=f"{base_url}/{endpoint}"
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {endpoint}: {e}")
        return None

# %%
fetch_data("match", params={"q": "upcoming"})
# Out:
# {'data': {'status': 200,
#   'segments': [{'team1': 'Oasis Gaming',
#     'team2': 'ZOL Esports',
#     'flag1': 'flag_ph',
#     'flag2': 'flag_ph',
#     'time_until_match': '2h 1m from now',
#     'match_series': 'Bracket Stage: Lower Final',
#     'match_event': 'Challengers League 2024 Philippines: Split 2',
#     'unix_timestamp': '2024-07-26 06:00:00',
#     'match_page': 'https://www.vlr.gg/360912/oasis-gaming-vs-zol-esports-challengers-league-2024-philippines-split-2-lf'},
#    {'team1': 'Bigetron Arctic',
#     'team2': 'BOOM Esports',
#     'flag1': 'flag_id',
#     'flag2': 'flag_id',
#     'time_until_match': '3h 1m from now',
#     'match_series': 'Main Event: Lower Round 2',
#     'match_event': 'Challengers League 2024 Indonesia: Split 2',
#     'unix_timestamp': '2024-07-26 07:00:00',
#     'match_page': 'https://www.vlr.gg/354553/bigetron-arctic-vs-boom-esports-challengers-league-2024-indonesia-split-2-lr2'},
#    {'team1': 'Mir Gaming GC',
#     'team2': 'SGA Incheon GC',
#     'flag1': 'flag_kr',
#     'flag2': 'flag_kr',
#     'time_until_match': '4h 1m from now',
#     'match_series': 'Main Event: Upper Semifinals',
#     'match_event': 'Game Changers 2024 Korea: Stage 2',
#     'unix_timestamp': '2024-07-26 08:00:00',
#     'match_page': 'https://www.vlr.gg/369955/mir-gaming-gc-vs-sga-incheon-gc-game-changers-2024-korea-stage-2-ubsf'},
#    {'team1': 'sisu',
#     'team2': 'Cardboard Dinosaur',
#     'flag1': 'flag_ph',
#     'flag2': 'flag_sg',
#     'time_until_match': '5h 1m from now',
#     'match_series': 'Playoffs: Lower Round 2',
#     'match_event': 'Game Changers 2024 Southeast Asia: Stage 2',
#     'unix_timestamp': '2024-07-26 09:00:00',
#     'match_page': 'https://www.vlr.gg/369927/sisu-vs-cardboard-dinosaur-game-changers-2024-southeast-asia-stage-2-lr2'},
#    {'team1': 'FULL SENSE',
#     'team2': 'Sharper Esport',
#     'flag1': 'flag_th',
#     'flag2': 'flag_th',
#     'time_until_match': '5h 1m from now',
#     'match_series': 'Main Event: Upper Semifinals',
#     'match_event': 'Challengers League 2024 Thailand: Ascension Qualifier Series',
#     'unix_timestamp': '2024-07-26 09:00:00',
#     'match_page': 'https://www.vlr.gg/379026/full-sense-vs-sharper-esport-challengers-league-2024-thailand-ascension-qualifier-series-ubsf'},
#    {'team1': 'Alter Ego',
#     'team2': 'ARF TEAM',
#     'flag1': 'flag_id',
#     'flag2': 'flag_id',
#     'time_until_match': '6h 1m from now',
#     'match_series': 'Main Event: Upper Final',
#     'match_event': 'Challengers League 2024 Indonesia: Split 2',
#     'unix_timestamp': '2024-07-26 10:00:00',
#     'match_page': 'https://www.vlr.gg/354549/alter-ego-vs-arf-team-challengers-league-2024-indonesia-split-2-ubf'},
#    {'team1': 'Nuclear GC',
#     'team2': 'URACHACHA GC',
#     'flag1': 'flag_kr',
#     'flag2': 'flag_kr',
#     'time_until_match': '7h 1m from now',
#     'match_series': 'Main Event: Upper Semifinals',
#     'match_event': 'Game Changers 2024 Korea: Stage 2',
#     'unix_timestamp': '2024-07-26 11:00:00',
#     'match_page': 'https://www.vlr.gg/369956/nuclear-gc-vs-urachacha-gc-game-changers-2024-korea-stage-2-ubsf'},
#    {'team1': 'invincible gc',
#     'team2': '4Fun',
#     'flag1': 'flag_th',
#     'flag2': 'flag_ph',
#     'time_until_match': '8h 1m from now',
#     'match_series': 'Playoffs: Lower Round 2',
#     'match_event': 'Game Changers 2024 Southeast Asia: Stage 2',
#     'unix_timestamp': '2024-07-26 12:00:00',
#     'match_page': 'https://www.vlr.gg/369928/invincible-gc-vs-4fun-game-changers-2024-southeast-asia-stage-2-lr2'},
#    {'team1': 'Made in Thailand',
#     'team2': 'XERXIA Esports',
#     'flag1': 'flag_th',
#     'flag2': 'flag_th',
#     'time_until_match': '8h 1m from now',
#     'match_series': 'Main Event: Upper Semifinals',
#     'match_event': 'Challengers League 2024 Thailand: Ascension Qualifier Series',
#     'unix_timestamp': '2024-07-26 12:00:00',
#     'match_page': 'https://www.vlr.gg/379027/made-in-thailand-vs-xerxia-esports-challengers-league-2024-thailand-ascension-qualifier-series-u'},
#    {'team1': 'PCIFIC Espor',
#     'team2': 'HOWL Esports',
#     'flag1': 'flag_tr',
#     'flag2': 'flag_tr',
#     'time_until_match': '10h 31m from now',
#     'match_series': 'Playoffs: Grand Final',
#     'match_event': 'Challengers League 2024 Türkiye Birlik: Split 2',
#     'unix_timestamp': '2024-07-26 14:30:00',
#     'match_page': 'https://www.vlr.gg/372381/pcific-espor-vs-howl-esports-challengers-league-2024-t-rkiye-birlik-split-2-playoffs-gf'},
#    {'team1': 'Acend',
#     'team2': 'Diamant Esports',
#     'flag1': 'flag_eu',
#     'flag2': 'flag_eu',
#     'time_until_match': '11h 1m from now',
#     'match_series': 'Playoffs: Lower Final',
#     'match_event': 'Challengers League 2024 East Surge: Split 2',
#     'unix_timestamp': '2024-07-26 15:00:00',
#     'match_page': 'https://www.vlr.gg/348780/acend-vs-diamant-esports-challengers-league-2024-east-surge-split-2-playoffs-lbf'},
#    {'team1': 'Apeks',
#     'team2': 'SweetNsour',
#     'flag1': 'flag_eu',
#     'flag2': 'flag_eu',
#     'time_until_match': '11h 1m from now',
#     'match_series': 'Playoffs: Grand Final',
#     'match_event': 'Challengers League 2024 North: Polaris Split 2',
#     'unix_timestamp': '2024-07-26 15:00:00',
#     'match_page': 'https://www.vlr.gg/370336/apeks-vs-sweetnsour-challengers-league-2024-north-polaris-split-2-playoffs-gf'},
#    {'team1': 'DSYRE',
#     'team2': 'NOVO Esports',
#     'flag1': 'flag_eu',
#     'flag2': 'flag_it',
#     'time_until_match': '12h 1m from now',
#     'match_series': 'Playoffs: Grand Final',
#     'match_event': 'Challengers League 2024 Italy Rinascimento: Split 2',
#     'unix_timestamp': '2024-07-26 16:00:00',
#     'match_page': 'https://www.vlr.gg/367225/dsyre-vs-novo-esports-challengers-league-2024-italy-rinascimento-split-2-playoffs-gf'},
#    {'team1': 'Team Falcons',
#     'team2': 'R8 Esports',
#     'flag1': 'flag_sa',
#     'flag2': 'flag_sa',
#     'time_until_match': '12h 1m from now',
#     'match_series': 'Main Event: Grand Final',
#     'match_event': 'Challengers League 2024 MENA: Regional Playoffs',
#     'unix_timestamp': '2024-07-26 16:00:00',
#     'match_page': 'https://www.vlr.gg/378383/team-falcons-vs-r8-esports-challengers-league-2024-mena-regional-playoffs-gf'},
#    {'team1': 'Stellae Gaming',
#     'team2': '2Game Esports',
#     'flag1': 'flag_br',
#     'flag2': 'flag_br',
#     'time_until_match': '16h 1m from now',
#     'match_series': 'Playoffs: Lower Round 2',
#     'match_event': 'Gamers Club Challengers League 2024 Brazil: Split 2',
#     'unix_timestamp': '2024-07-26 20:00:00',
#     'match_page': 'https://www.vlr.gg/370866/stellae-gaming-vs-2game-esports-gamers-club-challengers-league-2024-brazil-split-2-playoffs-lr2'},
#    {'team1': 'Oxygen Esports',
#     'team2': 'DarkZero Esports',
#     'flag1': 'flag_us',
#     'flag2': 'flag_us',
#     'time_until_match': '16h 1m from now',
#     'match_series': 'Finals: Lower Round 2',
#     'match_event': 'Challengers League 2024 North America: Stage 2',
#     'unix_timestamp': '2024-07-26 20:00:00',
#     'match_page': 'https://www.vlr.gg/372556/oxygen-esports-vs-darkzero-esports-challengers-league-2024-north-america-stage-2-lr2'},
#    {'team1': '9z Team',
#     'team2': 'RETA Esports',
#     'flag1': 'flag_ar',
#     'flag2': 'flag_cl',
#     'time_until_match': '16h 31m from now',
#     'match_series': 'Main Event: Opening',
#     'match_event': 'Challengers League 2024 LATAM: Regional Playoffs',
#     'unix_timestamp': '2024-07-26 20:30:00',
#     'match_page': 'https://www.vlr.gg/379338/9z-team-vs-reta-esports-challengers-league-2024-latam-regional-playoffs-opening'},
#    {'team1': 'Galorys',
#     'team2': 'THE 7',
#     'flag1': 'flag_br',
#     'flag2': 'flag_br',
#     'time_until_match': '19h 1m from now',
#     'match_series': 'Playoffs: Upper Final',
#     'match_event': 'Gamers Club Challengers League 2024 Brazil: Split 2',
#     'unix_timestamp': '2024-07-26 23:00:00',
#     'match_page': 'https://www.vlr.gg/370862/galorys-vs-the-7-gamers-club-challengers-league-2024-brazil-split-2-playoffs-ubf'}]}}

# %%
match_results=fetch_data("match", params={"q": "results"})
match_results
# Out:
# {'data': {'status': 200,
#   'segments': [{'team1': '2Game Esports',
#     'team2': 'TBK Esports',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_br',
#     'flag2': 'flag_br',
#     'time_completed': '5h 58m ago',
#     'round_info': ' Playoffs-Lower Round 1',
#     'tournament_name': 'Gamers Club Challengers League 2024 Brazil: Split 2',
#     'match_page': '/370865/2game-esports-vs-tbk-esports-gamers-club-challengers-league-2024-brazil-split-2-playoffs-lr1',
#     'tournament_icon': 'https://owcdn.net/img/66203e302897c.png'},
#    {'team1': 'SaD Esports',
#     'team2': 'TSM',
#     'score1': '1',
#     'score2': '2',
#     'flag1': 'flag_us',
#     'flag2': 'flag_us',
#     'time_completed': '6h 13m ago',
#     'round_info': ' Finals-Lower Round 1',
#     'tournament_name': 'Challengers League 2024 North America: Stage 2',
#     'match_page': '/372555/sad-esports-vs-tsm-challengers-league-2024-north-america-stage-2-lr1',
#     'tournament_icon': 'https://owcdn.net/img/63bc56190e38e.png'},
#    {'team1': 'Stellae Gaming',
#     'team2': 'RED Canids',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_br',
#     'flag2': 'flag_br',
#     'time_completed': '8h 13m ago',
#     'round_info': ' Playoffs-Lower Round 1',
#     'tournament_name': 'Gamers Club Challengers League 2024 Brazil: Split 2',
#     'match_page': '/370864/stellae-gaming-vs-red-canids-gamers-club-challengers-league-2024-brazil-split-2-playoffs-lr1',
#     'tournament_icon': 'https://owcdn.net/img/66203e302897c.png'},
#    {'team1': 'DarkZero Esports',
#     'team2': 'FLUFFY AIMERS',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_us',
#     'flag2': 'flag_us',
#     'time_completed': '8h 13m ago',
#     'round_info': ' Finals-Lower Round 1',
#     'tournament_name': 'Challengers League 2024 North America: Stage 2',
#     'match_page': '/372554/darkzero-esports-vs-fluffy-aimers-challengers-league-2024-north-america-stage-2-lr1',
#     'tournament_icon': 'https://owcdn.net/img/63bc56190e38e.png'},
#    {'team1': 'Diamant Esports',
#     'team2': 'trashcan',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_eu',
#     'flag2': 'flag_eu',
#     'time_completed': '9h 43m ago',
#     'round_info': ' Playoffs-Lower Round 1',
#     'tournament_name': 'Challengers League 2024 East Surge: Split 2',
#     'match_page': '/348779/diamant-esports-vs-trashcan-challengers-league-2024-east-surge-split-2-playoffs-lr1',
#     'tournament_icon': 'https://owcdn.net/img/63a1b49fcf14b.png'},
#    {'team1': 'Requiem',
#     'team2': 'SweetNsour',
#     'score1': '1',
#     'score2': '2',
#     'flag1': 'flag_eu',
#     'flag2': 'flag_eu',
#     'time_completed': '11h 13m ago',
#     'round_info': ' Playoffs-Lower Final',
#     'tournament_name': 'Challengers League 2024 North: Polaris Split 2',
#     'match_page': '/370338/requiem-vs-sweetnsour-challengers-league-2024-north-polaris-split-2-playoffs-lbf',
#     'tournament_icon': 'https://owcdn.net/img/63a1bab08cfca.png'},
#    {'team1': 'R8 Esports',
#     'team2': 'NASR Esports',
#     'score1': '3',
#     'score2': '2',
#     'flag1': 'flag_sa',
#     'flag2': 'flag_eu',
#     'time_completed': '12h 13m ago',
#     'round_info': ' Main Event-Lower Final',
#     'tournament_name': 'Challengers League 2024 MENA: Regional Playoffs',
#     'match_page': '/378385/r8-esports-vs-nasr-esports-challengers-league-2024-mena-regional-playoffs-lbf',
#     'tournament_icon': 'https://owcdn.net/img/63d7ef4687006.png'},
#    {'team1': 'Acend',
#     'team2': 'GoNext Esports',
#     'score1': '1',
#     'score2': '2',
#     'flag1': 'flag_eu',
#     'flag2': 'flag_eu',
#     'time_completed': '13h 13m ago',
#     'round_info': ' Playoffs-Upper Final',
#     'tournament_name': 'Challengers League 2024 East Surge: Split 2',
#     'match_page': '/348777/acend-vs-gonext-esports-challengers-league-2024-east-surge-split-2-playoffs-ubf',
#     'tournament_icon': 'https://owcdn.net/img/63a1b49fcf14b.png'},
#    {'team1': 'HOWL Esports',
#     'team2': 'Galakticos',
#     'score1': '3',
#     'score2': '1',
#     'flag1': 'flag_tr',
#     'flag2': 'flag_tr',
#     'time_completed': '13h 43m ago',
#     'round_info': ' Playoffs-Lower Final',
#     'tournament_name': 'Challengers League 2024 Türkiye Birlik: Split 2',
#     'match_page': '/372385/howl-esports-vs-galakticos-challengers-league-2024-t-rkiye-birlik-split-2-playoffs-lbf',
#     'tournament_icon': 'https://owcdn.net/img/63a1b2d391745.png'},
#    {'team1': '4Fun',
#     'team2': 'Avernus Esports GC',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_ph',
#     'flag2': 'flag_ph',
#     'time_completed': '15h 13m ago',
#     'round_info': ' Playoffs-Lower Round 1',
#     'tournament_name': 'Game Changers 2024 Southeast Asia: Stage 2',
#     'match_page': '/369926/4fun-vs-avernus-esports-gc-game-changers-2024-southeast-asia-stage-2-lr1',
#     'tournament_icon': 'https://owcdn.net/img/604be13d01964.png'},
#    {'team1': 'LILAX',
#     'team2': 'Cardboard Dinosaur',
#     'score1': '1',
#     'score2': '2',
#     'flag1': 'flag_th',
#     'flag2': 'flag_sg',
#     'time_completed': '18h 43m ago',
#     'round_info': ' Playoffs-Lower Round 1',
#     'tournament_name': 'Game Changers 2024 Southeast Asia: Stage 2',
#     'match_page': '/369925/lilax-vs-cardboard-dinosaur-game-changers-2024-southeast-asia-stage-2-lr1',
#     'tournament_icon': 'https://owcdn.net/img/604be13d01964.png'},
#    {'team1': 'THE HERO DETA',
#     'team2': 'Bigetron Arctic',
#     'score1': '0',
#     'score2': '2',
#     'flag1': 'flag_id',
#     'flag2': 'flag_id',
#     'time_completed': '19h 8m ago',
#     'round_info': ' Main Event-Lower Round 1',
#     'tournament_name': 'Challengers League 2024 Indonesia: Split 2',
#     'match_page': '/354551/the-hero-deta-vs-bigetron-arctic-challengers-league-2024-indonesia-split-2-lr1',
#     'tournament_icon': 'https://owcdn.net/img/6009f963577f4.png'},
#    {'team1': 'BOOM Esports',
#     'team2': 'Cynical',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_id',
#     'flag2': 'flag_id',
#     'time_completed': '21h 58m ago',
#     'round_info': ' Main Event-Lower Round 1',
#     'tournament_name': 'Challengers League 2024 Indonesia: Split 2',
#     'match_page': '/354552/boom-esports-vs-cynical-challengers-league-2024-indonesia-split-2-lr1',
#     'tournament_icon': 'https://owcdn.net/img/6009f963577f4.png'},
#    {'team1': 'sisu',
#     'team2': 'BOBA',
#     'score1': '1',
#     'score2': '2',
#     'flag1': 'flag_ph',
#     'flag2': 'flag_un',
#     'time_completed': '22h 13m ago',
#     'round_info': ' Playoffs-Upper Semifinals',
#     'tournament_name': 'Game Changers 2024 Southeast Asia: Stage 2',
#     'match_page': '/369924/sisu-vs-boba-game-changers-2024-southeast-asia-stage-2-ubsf',
#     'tournament_icon': 'https://owcdn.net/img/604be13d01964.png'},
#    {'team1': 'ARF TEAM',
#     'team2': 'THE HERO DETA',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_id',
#     'flag2': 'flag_id',
#     'time_completed': '1d 0h ago',
#     'round_info': ' Main Event-Upper Semifinals',
#     'tournament_name': 'Challengers League 2024 Indonesia: Split 2',
#     'match_page': '/354548/arf-team-vs-the-hero-deta-challengers-league-2024-indonesia-split-2-ubsf',
#     'tournament_icon': 'https://owcdn.net/img/6009f963577f4.png'},
#    {'team1': 'Blinn',
#     'team2': 'Moist x Shopify',
#     'score1': '0',
#     'score2': '2',
#     'flag1': 'flag_us',
#     'flag2': 'flag_us',
#     'time_completed': '1d 4h ago',
#     'round_info': ' Finals-Upper Semifinals',
#     'tournament_name': 'Challengers League 2024 North America: Stage 2',
#     'match_page': '/372550/blinn-vs-moist-x-shopify-challengers-league-2024-north-america-stage-2-ubsf',
#     'tournament_icon': 'https://owcdn.net/img/63bc56190e38e.png'},
#    {'team1': 'Team Leveling',
#     'team2': 'paprica picante',
#     'score1': '2',
#     'score2': '1',
#     'flag1': 'flag_br',
#     'flag2': 'flag_br',
#     'time_completed': '1d 6h ago',
#     'round_info': ' Main Event-Lower Round 1',
#     'tournament_name': 'Game Changers 2024 Brazil: Series 2',
#     'match_page': '/379186/team-leveling-vs-paprica-picante-game-changers-2024-brazil-series-2-lr1',
#     'tournament_icon': 'https://owcdn.net/img/604be13d01964.png'},
#    {'team1': 'Team Falcons',
#     'team2': 'R8 Esports',
#     'score1': '2',
#     'score2': '1',
#     'flag1': 'flag_sa',
#     'flag2': 'flag_sa',
#     'time_completed': '1d 7h ago',
#     'round_info': ' Main Event-Upper Final',
#     'tournament_name': 'Challengers League 2024 MENA: Regional Playoffs',
#     'match_page': '/378382/team-falcons-vs-r8-esports-challengers-league-2024-mena-regional-playoffs-ubf',
#     'tournament_icon': 'https://owcdn.net/img/63d7ef4687006.png'},
#    {'team1': 'Oxygen Esports',
#     'team2': 'M80',
#     'score1': '1',
#     'score2': '2',
#     'flag1': 'flag_us',
#     'flag2': 'flag_ca',
#     'time_completed': '1d 8h ago',
#     'round_info': ' Finals-Upper Semifinals',
#     'tournament_name': 'Challengers League 2024 North America: Stage 2',
#     'match_page': '/372551/oxygen-esports-vs-m80-challengers-league-2024-north-america-stage-2-ubsf',
#     'tournament_icon': 'https://owcdn.net/img/63bc56190e38e.png'},
#    {'team1': 'PS5PATAS',
#     'team2': 'revoada',
#     'score1': '0',
#     'score2': '2',
#     'flag1': 'flag_br',
#     'flag2': 'flag_br',
#     'time_completed': '1d 8h ago',
#     'round_info': ' Main Event-Lower Round 1',
#     'tournament_name': 'Game Changers 2024 Brazil: Series 2',
#     'match_page': '/379185/ps5patas-vs-revoada-game-changers-2024-brazil-series-2-lr1',
#     'tournament_icon': 'https://owcdn.net/img/604be13d01964.png'},
#    {'team1': 'PCIFIC Espor',
#     'team2': 'HOWL Esports',
#     'score1': '2',
#     'score2': '1',
#     'flag1': 'flag_tr',
#     'flag2': 'flag_tr',
#     'time_completed': '1d 10h ago',
#     'round_info': ' Playoffs-Upper Final',
#     'tournament_name': 'Challengers League 2024 Türkiye Birlik: Split 2',
#     'match_page': '/372380/pcific-espor-vs-howl-esports-challengers-league-2024-t-rkiye-birlik-split-2-playoffs-ubf',
#     'tournament_icon': 'https://owcdn.net/img/63a1b2d391745.png'},
#    {'team1': 'Apeks',
#     'team2': 'Requiem',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_eu',
#     'flag2': 'flag_eu',
#     'time_completed': '1d 11h ago',
#     'round_info': ' Playoffs-Upper Final',
#     'tournament_name': 'Challengers League 2024 North: Polaris Split 2',
#     'match_page': '/370335/apeks-vs-requiem-challengers-league-2024-north-polaris-split-2-playoffs-ubf',
#     'tournament_icon': 'https://owcdn.net/img/63a1bab08cfca.png'},
#    {'team1': 'NASR Esports',
#     'team2': 'United Gaming',
#     'score1': '2',
#     'score2': '1',
#     'flag1': 'flag_eu',
#     'flag2': 'flag_kw',
#     'time_completed': '1d 12h ago',
#     'round_info': ' Main Event-Lower Round 1',
#     'tournament_name': 'Challengers League 2024 MENA: Regional Playoffs',
#     'match_page': '/378384/nasr-esports-vs-united-gaming-challengers-league-2024-mena-regional-playoffs-lr1',
#     'tournament_icon': 'https://owcdn.net/img/63d7ef4687006.png'},
#    {'team1': 'OnlyFins',
#     'team2': 'SweetNsour',
#     'score1': '0',
#     'score2': '2',
#     'flag1': 'flag_fi',
#     'flag2': 'flag_eu',
#     'time_completed': '1d 14h ago',
#     'round_info': ' Playoffs-Lower Round 1',
#     'tournament_name': 'Challengers League 2024 North: Polaris Split 2',
#     'match_page': '/370337/onlyfins-vs-sweetnsour-challengers-league-2024-north-polaris-split-2-playoffs-lr1',
#     'tournament_icon': 'https://owcdn.net/img/63a1bab08cfca.png'},
#    {'team1': 'Galakticos',
#     'team2': 'Galatasaray Esports',
#     'score1': '2',
#     'score2': '1',
#     'flag1': 'flag_tr',
#     'flag2': 'flag_tr',
#     'time_completed': '1d 14h ago',
#     'round_info': ' Playoffs-Lower Round 2',
#     'tournament_name': 'Challengers League 2024 Türkiye Birlik: Split 2',
#     'match_page': '/372384/galakticos-vs-galatasaray-esports-challengers-league-2024-t-rkiye-birlik-split-2-playoffs-lr2',
#     'tournament_icon': 'https://owcdn.net/img/63a1b2d391745.png'},
#    {'team1': 'BOOM Esports',
#     'team2': 'Alter Ego',
#     'score1': '1',
#     'score2': '2',
#     'flag1': 'flag_id',
#     'flag2': 'flag_id',
#     'time_completed': '1d 18h ago',
#     'round_info': ' Main Event-Upper Semifinals',
#     'tournament_name': 'Challengers League 2024 Indonesia: Split 2',
#     'match_page': '/354547/boom-esports-vs-alter-ego-challengers-league-2024-indonesia-split-2-ubsf',
#     'tournament_icon': 'https://owcdn.net/img/6009f963577f4.png'},
#    {'team1': 'Xipto Esports',
#     'team2': 'invincible gc',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_ph',
#     'flag2': 'flag_th',
#     'time_completed': '1d 19h ago',
#     'round_info': ' Playoffs-Upper Semifinals',
#     'tournament_name': 'Game Changers 2024 Southeast Asia: Stage 2',
#     'match_page': '/369923/xipto-esports-vs-invincible-gc-game-changers-2024-southeast-asia-stage-2-ubsf',
#     'tournament_icon': 'https://owcdn.net/img/604be13d01964.png'},
#    {'team1': 'Dplus Esports',
#     'team2': 'Nongshim RedForce',
#     'score1': '1',
#     'score2': '3',
#     'flag1': 'flag_kr',
#     'flag2': 'flag_kr',
#     'time_completed': '1d 20h ago',
#     'round_info': ' Playoffs-Lower Final',
#     'tournament_name': 'WDG Challengers League 2024 Korea: Split 2',
#     'match_page': '/369430/dplus-esports-vs-nongshim-redforce-wdg-challengers-league-2024-korea-split-2-lbf',
#     'tournament_icon': 'https://owcdn.net/img/6009f963577f4.png'},
#    {'team1': 'ZETA DIVISION GC',
#     'team2': 'FENNEL GC',
#     'score1': '3',
#     'score2': '1',
#     'flag1': 'flag_jp',
#     'flag2': 'flag_jp',
#     'time_completed': '1d 20h ago',
#     'round_info': ' Main Stage-Grand Final',
#     'tournament_name': 'Game Changers 2024 Japan: Split 2',
#     'match_page': '/372245/zeta-division-gc-vs-fennel-gc-game-changers-2024-japan-split-2-gf',
#     'tournament_icon': 'https://owcdn.net/img/604be13d01964.png'},
#    {'team1': 'THE HERO DETA',
#     'team2': 'Cynical',
#     'score1': '2',
#     'score2': '1',
#     'flag1': 'flag_id',
#     'flag2': 'flag_id',
#     'time_completed': '1d 21h ago',
#     'round_info': ' Main Event-Upper Round 1',
#     'tournament_name': 'Challengers League 2024 Indonesia: Split 2',
#     'match_page': '/354546/the-hero-deta-vs-cynical-challengers-league-2024-indonesia-split-2-ur1',
#     'tournament_icon': 'https://owcdn.net/img/6009f963577f4.png'},
#    {'team1': 'Bigetron Arctic',
#     'team2': 'Alter Ego',
#     'score1': '0',
#     'score2': '2',
#     'flag1': 'flag_id',
#     'flag2': 'flag_id',
#     'time_completed': '2d 0h ago',
#     'round_info': ' Main Event-Upper Round 1',
#     'tournament_name': 'Challengers League 2024 Indonesia: Split 2',
#     'match_page': '/354545/bigetron-arctic-vs-alter-ego-challengers-league-2024-indonesia-split-2-ur1',
#     'tournament_icon': 'https://owcdn.net/img/6009f963577f4.png'},
#    {'team1': 'DarkZero Esports',
#     'team2': 'Blinn',
#     'score1': '1',
#     'score2': '2',
#     'flag1': 'flag_us',
#     'flag2': 'flag_us',
#     'time_completed': '2d 5h ago',
#     'round_info': ' Finals-Upper Quarterfinals',
#     'tournament_name': 'Challengers League 2024 North America: Stage 2',
#     'match_page': '/372546/darkzero-esports-vs-blinn-challengers-league-2024-north-america-stage-2-ubqf',
#     'tournament_icon': 'https://owcdn.net/img/63bc56190e38e.png'},
#    {'team1': 'LOUD GC',
#     'team2': 'paprica picante',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_br',
#     'flag2': 'flag_br',
#     'time_completed': '2d 6h ago',
#     'round_info': ' Main Event-Upper Quarterfinals',
#     'tournament_name': 'Game Changers 2024 Brazil: Series 2',
#     'match_page': '/379180/loud-gc-vs-paprica-picante-game-changers-2024-brazil-series-2-ubqf',
#     'tournament_icon': 'https://owcdn.net/img/604be13d01964.png'},
#    {'team1': 'Moist x Shopify',
#     'team2': 'FLUFFY AIMERS',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_us',
#     'flag2': 'flag_us',
#     'time_completed': '2d 8h ago',
#     'round_info': ' Finals-Upper Quarterfinals',
#     'tournament_name': 'Challengers League 2024 North America: Stage 2',
#     'match_page': '/372547/moist-x-shopify-vs-fluffy-aimers-challengers-league-2024-north-america-stage-2-ubqf',
#     'tournament_icon': 'https://owcdn.net/img/63bc56190e38e.png'},
#    {'team1': 'MIBR GC',
#     'team2': 'Team Leveling',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_br',
#     'flag2': 'flag_br',
#     'time_completed': '2d 8h ago',
#     'round_info': ' Main Event-Upper Quarterfinals',
#     'tournament_name': 'Game Changers 2024 Brazil: Series 2',
#     'match_page': '/379179/mibr-gc-vs-team-leveling-game-changers-2024-brazil-series-2-ubqf',
#     'tournament_icon': 'https://owcdn.net/img/604be13d01964.png'},
#    {'team1': 'R8 Esports',
#     'team2': 'United Gaming',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_sa',
#     'flag2': 'flag_kw',
#     'time_completed': '2d 9h ago',
#     'round_info': ' Main Event-Upper Semifinals',
#     'tournament_name': 'Challengers League 2024 MENA: Regional Playoffs',
#     'match_page': '/378381/r8-esports-vs-united-gaming-challengers-league-2024-mena-regional-playoffs-ubsf',
#     'tournament_icon': 'https://owcdn.net/img/63d7ef4687006.png'},
#    {'team1': 'TBS GC',
#     'team2': 'revoada',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_br',
#     'flag2': 'flag_br',
#     'time_completed': '2d 10h ago',
#     'round_info': ' Main Event-Upper Quarterfinals',
#     'tournament_name': 'Game Changers 2024 Brazil: Series 2',
#     'match_page': '/379178/tbs-gc-vs-revoada-game-changers-2024-brazil-series-2-ubqf',
#     'tournament_icon': 'https://owcdn.net/img/604be13d01964.png'},
#    {'team1': 'Fire Flux Esports',
#     'team2': 'Galatasaray Esports',
#     'score1': '1',
#     'score2': '2',
#     'flag1': 'flag_tr',
#     'flag2': 'flag_tr',
#     'time_completed': '2d 11h ago',
#     'round_info': ' Playoffs-Lower Round 1',
#     'tournament_name': 'Challengers League 2024 Türkiye Birlik: Split 2',
#     'match_page': '/372383/fire-flux-esports-vs-galatasaray-esports-challengers-league-2024-t-rkiye-birlik-split-2-playoffs',
#     'tournament_icon': 'https://owcdn.net/img/63a1b2d391745.png'},
#    {'team1': 'SweetNsour',
#     'team2': 'Requiem',
#     'score1': '1',
#     'score2': '2',
#     'flag1': 'flag_eu',
#     'flag2': 'flag_eu',
#     'time_completed': '2d 12h ago',
#     'round_info': ' Playoffs-Upper Semifinals',
#     'tournament_name': 'Challengers League 2024 North: Polaris Split 2',
#     'match_page': '/370334/sweetnsour-vs-requiem-challengers-league-2024-north-polaris-split-2-playoffs-ubsf',
#     'tournament_icon': 'https://owcdn.net/img/63a1bab08cfca.png'},
#    {'team1': 'Team Falcons',
#     'team2': 'NASR Esports',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_sa',
#     'flag2': 'flag_eu',
#     'time_completed': '2d 12h ago',
#     'round_info': ' Main Event-Upper Semifinals',
#     'tournament_name': 'Challengers League 2024 MENA: Regional Playoffs',
#     'match_page': '/378380/team-falcons-vs-nasr-esports-challengers-league-2024-mena-regional-playoffs-ubsf',
#     'tournament_icon': 'https://owcdn.net/img/63d7ef4687006.png'},
#    {'team1': 'Apeks',
#     'team2': 'OnlyFins',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_eu',
#     'flag2': 'flag_fi',
#     'time_completed': '2d 14h ago',
#     'round_info': ' Playoffs-Upper Semifinals',
#     'tournament_name': 'Challengers League 2024 North: Polaris Split 2',
#     'match_page': '/370333/apeks-vs-onlyfins-challengers-league-2024-north-polaris-split-2-playoffs-ubsf',
#     'tournament_icon': 'https://owcdn.net/img/63a1bab08cfca.png'},
#    {'team1': 'Papara SuperMassive',
#     'team2': 'Galakticos',
#     'score1': '1',
#     'score2': '2',
#     'flag1': 'flag_tr',
#     'flag2': 'flag_tr',
#     'time_completed': '2d 14h ago',
#     'round_info': ' Playoffs-Lower Round 1',
#     'tournament_name': 'Challengers League 2024 Türkiye Birlik: Split 2',
#     'match_page': '/372382/papara-supermassive-vs-galakticos-challengers-league-2024-t-rkiye-birlik-split-2-playoffs-lr1',
#     'tournament_icon': 'https://owcdn.net/img/63a1b2d391745.png'},
#    {'team1': 'BOBA',
#     'team2': 'Avernus Esports GC',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_un',
#     'flag2': 'flag_ph',
#     'time_completed': '2d 16h ago',
#     'round_info': ' Playoffs-Upper Quarterfinals',
#     'tournament_name': 'Game Changers 2024 Southeast Asia: Stage 2',
#     'match_page': '/369922/boba-vs-avernus-esports-gc-game-changers-2024-southeast-asia-stage-2-ubqf',
#     'tournament_icon': 'https://owcdn.net/img/604be13d01964.png'},
#    {'team1': 'JustUs',
#     'team2': 'ZOL Esports',
#     'score1': '1',
#     'score2': '2',
#     'flag1': 'flag_ph',
#     'flag2': 'flag_ph',
#     'time_completed': '2d 18h ago',
#     'round_info': ' Bracket Stage-Lower Round 1',
#     'tournament_name': 'Challengers League 2024 Philippines: Split 2',
#     'match_page': '/360911/justus-vs-zol-esports-challengers-league-2024-philippines-split-2-lr1',
#     'tournament_icon': 'https://owcdn.net/img/6009f963577f4.png'},
#    {'team1': 'sisu',
#     'team2': '4Fun',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_ph',
#     'flag2': 'flag_ph',
#     'time_completed': '2d 19h ago',
#     'round_info': ' Playoffs-Upper Quarterfinals',
#     'tournament_name': 'Game Changers 2024 Southeast Asia: Stage 2',
#     'match_page': '/369921/sisu-vs-4fun-game-changers-2024-southeast-asia-stage-2-ubqf',
#     'tournament_icon': 'https://owcdn.net/img/604be13d01964.png'},
#    {'team1': 'FENNEL GC',
#     'team2': 'REIGNITE Lily',
#     'score1': '3',
#     'score2': '2',
#     'flag1': 'flag_jp',
#     'flag2': 'flag_jp',
#     'time_completed': '2d 20h ago',
#     'round_info': ' Main Stage-Lower Final',
#     'tournament_name': 'Game Changers 2024 Japan: Split 2',
#     'match_page': '/372251/fennel-gc-vs-reignite-lily-game-changers-2024-japan-split-2-lbf',
#     'tournament_icon': 'https://owcdn.net/img/604be13d01964.png'},
#    {'team1': 'Oasis Gaming',
#     'team2': 'NAOS',
#     'score1': '0',
#     'score2': '2',
#     'flag1': 'flag_ph',
#     'flag2': 'flag_ph',
#     'time_completed': '2d 21h ago',
#     'round_info': ' Bracket Stage-Upper Final',
#     'tournament_name': 'Challengers League 2024 Philippines: Split 2',
#     'match_page': '/360910/oasis-gaming-vs-naos-challengers-league-2024-philippines-split-2-ubf',
#     'tournament_icon': 'https://owcdn.net/img/6009f963577f4.png'},
#    {'team1': 'Oxygen Esports',
#     'team2': 'SaD Esports',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_us',
#     'flag2': 'flag_us',
#     'time_completed': '3d 5h ago',
#     'round_info': ' Finals-Upper Quarterfinals',
#     'tournament_name': 'Challengers League 2024 North America: Stage 2',
#     'match_page': '/372548/oxygen-esports-vs-sad-esports-challengers-league-2024-north-america-stage-2-ubqf',
#     'tournament_icon': 'https://owcdn.net/img/63bc56190e38e.png'},
#    {'team1': 'Team Liquid Brazil',
#     'team2': 'PS5PATAS',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_br',
#     'flag2': 'flag_br',
#     'time_completed': '3d 7h ago',
#     'round_info': ' Main Event-Upper Quarterfinals',
#     'tournament_name': 'Game Changers 2024 Brazil: Series 2',
#     'match_page': '/379177/team-liquid-brazil-vs-ps5patas-game-changers-2024-brazil-series-2-ubqf',
#     'tournament_icon': 'https://owcdn.net/img/604be13d01964.png'},
#    {'team1': 'M80',
#     'team2': 'TSM',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_ca',
#     'flag2': 'flag_us',
#     'time_completed': '3d 8h ago',
#     'round_info': ' Finals-Upper Quarterfinals',
#     'tournament_name': 'Challengers League 2024 North America: Stage 2',
#     'match_page': '/372549/m80-vs-tsm-challengers-league-2024-north-america-stage-2-ubqf',
#     'tournament_icon': 'https://owcdn.net/img/63bc56190e38e.png'}]}}

# %%
#Checks the API health
health_status=fetch_data("health")
health_status
# Out:
# 'Healthy: OK'

# %%
results = fetch_data("match", params={"q": "results"})
print(results)
# Out:
# {'data': {'status': 200, 'segments': [{'team1': '2Game Esports', 'team2': 'TBK Esports', 'score1': '2', 'score2': '0', 'flag1': 'flag_br', 'flag2': 'flag_br', 'time_completed': '5h 55m ago', 'round_info': ' Playoffs-Lower Round 1', 'tournament_name': 'Gamers Club Challengers League 2024 Brazil: Split 2', 'match_page': '/370865/2game-esports-vs-tbk-esports-gamers-club-challengers-league-2024-brazil-split-2-playoffs-lr1', 'tournament_icon': 'https://owcdn.net/img/66203e302897c.png'}, {'team1': 'SaD Esports', 'team2': 'TSM', 'score1': '1', 'score2': '2', 'flag1': 'flag_us', 'flag2': 'flag_us', 'time_completed': '6h 10m ago', 'round_info': ' Finals-Lower Round 1', 'tournament_name': 'Challengers League 2024 North America: Stage 2', 'match_page': '/372555/sad-esports-vs-tsm-challengers-league-2024-north-america-stage-2-lr1', 'tournament_icon': 'https://owcdn.net/img/63bc56190e38e.png'}, {'team1': 'Stellae Gaming', 'team2': 'RED Canids', 'score1': '2', 'score2': '0', 'flag1': 'flag_br', 'flag2': 'flag_br', 'time_completed': '8h 10m ago', 'round_info': ' Playoffs-Lower Round 1', 'tournament_name': 'Gamers Club Challengers League 2024 Brazil: Split 2', 'match_page': '/370864/stellae-gaming-vs-red-canids-gamers-club-challengers-league-2024-brazil-split-2-playoffs-lr1', 'tournament_icon': 'https://owcdn.net/img/66203e302897c.png'}, {'team1': 'DarkZero Esports', 'team2': 'FLUFFY AIMERS', 'score1': '2', 'score2': '0', 'flag1': 'flag_us', 'flag2': 'flag_us', 'time_completed': '8h 10m ago', 'round_info': ' Finals-Lower Round 1', 'tournament_name': 'Challengers League 2024 North America: Stage 2', 'match_page': '/372554/darkzero-esports-vs-fluffy-aimers-challengers-league-2024-north-america-stage-2-lr1', 'tournament_icon': 'https://owcdn.net/img/63bc56190e38e.png'}, {'team1': 'Diamant Esports', 'team2': 'trashcan', 'score1': '2', 'score2': '0', 'flag1': 'flag_eu', 'flag2': 'flag_eu', 'time_completed': '9h 40m ago', 'round_info': ' Playoffs-Lower Round 1', 'tournament_name': 'Challengers League 2024 East Surge: Split 2', 'match_page': '/348779/diamant-esports-vs-trashcan-challengers-league-2024-east-surge-split-2-playoffs-lr1', 'tournament_icon': 'https://owcdn.net/img/63a1b49fcf14b.png'}, {'team1': 'Requiem', 'team2': 'SweetNsour', 'score1': '1', 'score2': '2', 'flag1': 'flag_eu', 'flag2': 'flag_eu', 'time_completed': '11h 10m ago', 'round_info': ' Playoffs-Lower Final', 'tournament_name': 'Challengers League 2024 North: Polaris Split 2', 'match_page': '/370338/requiem-vs-sweetnsour-challengers-league-2024-north-polaris-split-2-playoffs-lbf', 'tournament_icon': 'https://owcdn.net/img/63a1bab08cfca.png'}, {'team1': 'R8 Esports', 'team2': 'NASR Esports', 'score1': '3', 'score2': '2', 'flag1': 'flag_sa', 'flag2': 'flag_eu', 'time_completed': '12h 10m ago', 'round_info': ' Main Event-Lower Final', 'tournament_name': 'Challengers League 2024 MENA: Regional Playoffs', 'match_page': '/378385/r8-esports-vs-nasr-esports-challengers-league-2024-mena-regional-playoffs-lbf', 'tournament_icon': 'https://owcdn.net/img/63d7ef4687006.png'}, {'team1': 'Acend', 'team2': 'GoNext Esports', 'score1': '1', 'score2': '2', 'flag1': 'flag_eu', 'flag2': 'flag_eu', 'time_completed': '13h 10m ago', 'round_info': ' Playoffs-Upper Final', 'tournament_name': 'Challengers League 2024 East Surge: Split 2', 'match_page': '/348777/acend-vs-gonext-esports-challengers-league-2024-east-surge-split-2-playoffs-ubf', 'tournament_icon': 'https://owcdn.net/img/63a1b49fcf14b.png'}, {'team1': 'HOWL Esports', 'team2': 'Galakticos', 'score1': '3', 'score2': '1', 'flag1': 'flag_tr', 'flag2': 'flag_tr', 'time_completed': '13h 40m ago', 'round_info': ' Playoffs-Lower Final', 'tournament_name': 'Challengers League 2024 Türkiye Birlik: Split 2', 'match_page': '/372385/howl-esports-vs-galakticos-challengers-league-2024-t-rkiye-birlik-split-2-playoffs-lbf', 'tournament_icon': 'https://owcdn.net/img/63a1b2d391745.png'}, {'team1': '4Fun', 'team2': 'Avernus Esports GC', 'score1': '2', 'score2': '0 ...
