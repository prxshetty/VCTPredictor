# %%
import requests
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       4 from sklearn.preprocessing import StandardScaler
#       5 from sklearn.model_selection import train_test_split
# ----> 6 from tensorflow.keras.model import Sequential
#       7 from tensorflow.keras.layers import Dense
#
# ModuleNotFoundError: No module named 'tensorflow.keras.model'

# %%
def fetch_data(endpoint, params=None):
    base_url = "https://vlrggapi.vercel.app"
    url=f"{base_url}/{endpoint}"
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {endpoint}: {e}")
        return None

# %%
fetch_data("match", params={"q": "upcoming"})
# Out:
# {'data': {'status': 200,
#   'segments': [{'team1': 'G2 Esports',
#     'team2': 'Paper Rex',
#     'flag1': 'flag_us',
#     'flag2': 'flag_sg',
#     'time_until_match': '5h 51m from now',
#     'match_series': 'Group Stage: Opening (D)',
#     'match_event': 'Valorant Champions 2024',
#     'unix_timestamp': '2024-08-04 08:00:00',
#     'match_page': 'https://www.vlr.gg/378674/g2-esports-vs-paper-rex-valorant-champions-2024-opening-d'},
#    {'team1': 'EDward Gaming',
#     'team2': 'FUT Esports',
#     'flag1': 'flag_cn',
#     'flag2': 'flag_tr',
#     'time_until_match': '8h 51m from now',
#     'match_series': 'Group Stage: Opening (D)',
#     'match_event': 'Valorant Champions 2024',
#     'unix_timestamp': '2024-08-04 11:00:00',
#     'match_page': 'https://www.vlr.gg/378673/edward-gaming-vs-fut-esports-valorant-champions-2024-opening-d'},
#    {'team1': 'Gen.G',
#     'team2': 'Team Heretics',
#     'flag1': 'flag_kr',
#     'flag2': 'flag_eu',
# ...

# %%
match_results=fetch_data("match", params={"q": "results"})
match_results
# Out:
# {'data': {'status': 200,
#   'segments': [{'team1': 'Team Vitality',
#     'team2': 'Trace Esports',
#     'score1': '1',
#     'score2': '2',
#     'flag1': 'flag_eu',
#     'flag2': 'flag_cn',
#     'time_completed': '15h 40m ago',
#     'round_info': ' Group Stage-Opening (C)',
#     'tournament_name': 'Valorant Champions 2024',
#     'match_page': '/378669/team-vitality-vs-trace-esports-valorant-champions-2024-opening-c',
#     'tournament_icon': 'https://owcdn.net/img/63067806d167d.png'},
#    {'team1': 'LEVIATÁN',
#     'team2': 'Talon Esports',
#     'score1': '2',
#     'score2': '0',
#     'flag1': 'flag_cl',
#     'flag2': 'flag_th',
#     'time_completed': '18h 10m ago',
#     'round_info': ' Group Stage-Opening (C)',
#     'tournament_name': 'Valorant Champions 2024',
#     'match_page': '/378667/leviat-n-vs-talon-esports-valorant-champions-2024-opening-c',
#     'tournament_icon': 'https://owcdn.net/img/63067806d167d.png'},
#    {'team1': 'FNATIC',
# ...

# %%
#Checks the API health
health_status=fetch_data("health")
health_status
# Out:
# 'Healthy: OK'

# %%
results = fetch_data("match", params={"q": "results"})
print(results)
# Out:
# {'data': {'status': 200, 'segments': [{'team1': 'Team Vitality', 'team2': 'Trace Esports', 'score1': '1', 'score2': '2', 'flag1': 'flag_eu', 'flag2': 'flag_cn', 'time_completed': '15h 40m ago', 'round_info': ' Group Stage-Opening (C)', 'tournament_name': 'Valorant Champions 2024', 'match_page': '/378669/team-vitality-vs-trace-esports-valorant-champions-2024-opening-c', 'tournament_icon': 'https://owcdn.net/img/63067806d167d.png'}, {'team1': 'LEVIATÁN', 'team2': 'Talon Esports', 'score1': '2', 'score2': '0', 'flag1': 'flag_cl', 'flag2': 'flag_th', 'time_completed': '18h 10m ago', 'round_info': ' Group Stage-Opening (C)', 'tournament_name': 'Valorant Champions 2024', 'match_page': '/378667/leviat-n-vs-talon-esports-valorant-champions-2024-opening-c', 'tournament_icon': 'https://owcdn.net/img/63067806d167d.png'}, {'team1': 'FNATIC', 'team2': 'Bilibili Gaming', 'score1': '2', 'score2': '0', 'flag1': 'flag_eu', 'flag2': 'flag_cn', 'time_completed': '1d 15h ago', 'round_info': ' Group Stag
# ...
